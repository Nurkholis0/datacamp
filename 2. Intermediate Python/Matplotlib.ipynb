# %% [markdown]
# Name: Nurkholis \
# Source: <a href="datacamp.com" rel='noopener noreferrer' target='_blank'>Datacamp</a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Data visualization is a key skill for aspiring data scientists. Matplotlib makes it easy to create meaningful and insightful plots. In this chapter, you’ll learn how to build various types of plots, and customize them to be more visually appealing and interpretable.

# %% [markdown]
# ## Line Plot (1)

# %% [markdown]
# With matplotlib, you can create a bunch of different plots in Python. The most basic plot is the line plot. A general recipe is given here.

# %%
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()

# %% [markdown]
# The world bank has estimates of the world population for the years 1950 up to 2100. The years are loaded in your workspace as a list called $\color{blue}{\text{year}}$, and the corresponding populations as a list called $\color{blue}{\text{pop}}$.

# %%
import numpy as np
year = list(range(1950,2101))
pop  = list(np.loadtxt('pop1.txt', dtype=float))

# Print the last item from year and pop
print("year 1950 - 2100\t:", year)
print("population\t\t:", pop)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Make a line plot: year on the x-axis, pop on the y-axis
plt.plot(year,pop)

# Display the plot with plt.show()
plt.show()
# Out:
# year 1950 - 2100	: [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100]
# ...

# %% [markdown]
# ## Line Plot (2): Interpretation

# %% [markdown]
# Have another look at the plot you created in the previous exercise; it's shown on the right. Based on the plot, in approximately what year will there be more than ten billion human beings on this planet?

# %%
# Make a line plot: year on the x-axis, pop on the y-axis
plt.plot(year,pop)

# Display the plot with plt.show()
plt.show()

# %% [markdown]
# **Possible answers:**
# <ul>
#     <li><input type="checkbox"> 2040</li>
#     <li><input type="checkbox" checked> $\color{blue}{\text{2060}}$</li>
#     <li><input type="checkbox"> 2085</li>
#     <li><input type="checkbox"> 2095</li>
# </ul>

# %% [markdown]
# ## Line Plot (3)

# %% [markdown]
# Now that you've built your first line plot, let's start working on the data that professor Hans Rosling used to build his beautiful bubble chart. It was collected in 2007. Two lists are available for you:

# %% [markdown]
# <ul>
#     <li>$\color{blue}{\text{life_exp}}$ which contains the life expectancy for each country and</li>
#     <li>$\color{blue}{\text{gdp_cap}}$, which contains the GDP per capita (i.e. per person) for each country expressed in US Dollars.</li>
# </ul>

# %% [markdown]
# GDP stands for Gross Domestic Product. It basically represents the size of the economy of a country. Divide this by the population and you get the GDP per capita.

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create gdp_cap for Gross Domestic Product per capita
gdp_cap = np_gdp_csv[:,6]

# create life_exp for  life expectancy for each country
life_exp = np_gdp_csv[:,5]

# Print out the 5 last item of gdp_cap and life_exp
print("gdp_cap for 5 elements\t:", gdp_cap[-5:])
print("life_exp for 5 elements\t:", life_exp[-5:])

# Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis
plt.plot(gdp_cap, life_exp)

# Display the plot
plt.show()
# Out:
# gdp_cap for 5 elements	: [2441.576404 3025.349798 2280.769906 1271.211593 469.7092981]
# life_exp for 5 elements	: [74.249 73.422 62.698 42.384 43.487]

# %% [markdown]
# ## Scatter Plot (1)

# %% [markdown]
# When you have a time scale along the horizontal axis, the line plot is your friend. But in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice. Below is an example of how to build a scatter plot.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Let's continue with the $\color{blue}{\text{gdp_cap}}$ versus $\color{blue}{\text{life_exp}}$ plot, the GDP and life expectancy data for different countries in 2007. Maybe a scatter plot will be a better alternative?

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create gdp_cap for Gross Domestic Product per capita
gdp_cap = np_gdp_csv[:,6]

# create life_exp for  life expectancy for each country
life_exp = np_gdp_csv[:,5]

# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()

# %% [markdown]
# ## Scatter Plot (2)

# %% [markdown]
# In the previous exercise, you saw that the higher GDP usually corresponds to a higher life expectancy. In other words, there is a positive correlation.

# %% [markdown]
# Do you think there's a relationship between population and life expectancy of a country? The list $\color{blue}{\text{life_exp}}$ from the previous exercise is already available. In addition, now also $\color{blue}{\text{pop}}$ is available, listing the corresponding populations for the countries in 2007. The populations are in millions of people.

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create pop for population
pop = np_gdp_csv[:,3]

# create life_exp for  life expectancy for each country
life_exp = np_gdp_csv[:,5]

# Build Scatter plot
plt.scatter(pop, life_exp)
# Show plot
plt.show()

# %% [markdown]
# ## Build a Histogram (1)

# %% [markdown]
# $\color{blue}{\text{life_exp}}$, the list containing data on the **life expectancy for different countries in 2007**.

# %% [markdown]
# To see how **life expectancy** in different countries is **distributed**, let's create a histogram of $\color{blue}{\text{life_exp}}$.

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create life_exp for  life expectancy for each country in 2007
life_exp = np_gdp_csv[:,5]

# Create histogram of life_exp data
plt.hist(life_exp, bins=None, edgecolor="black")
# Display histogram
plt.show()

# %% [markdown]
# ## Build a Histogram (2): bins

# %% [markdown]
# In the previous exercise, you didn't specify the number of bins. By default, **Python sets the number of bins to 10 in that case**. $\color{red}{\text{The number of bins}}$ is pretty important. Too few bins will oversimplify reality and won't show you the details. **Too many bins will overcomplicate reality and won't show the bigger picture**.

# %% [markdown]
# To **control the number of bins to divide your data in**, you can set $\color{blue}{\text{the bins argument}}$.

# %% [markdown]
# That's exactly what you'll do in this exercise. You'll be making two plots here. $\color{blue}{\text{plt.show()}}$ displays a plot; $\color{blue}{\text{plt.clf()}}$ cleans it up again so you can start afresh.

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create life_exp for  life expectancy for each country in 2007
life_exp = np_gdp_csv[:,5]

# Build histogram with 5 bins
plt.hist(life_exp, bins=5, edgecolor="blue", color="red")

# Show and clean up plot
plt.show()
plt.clf()

# Build histogram with 20 bins
plt.hist(life_exp, bins=20, edgecolor="red", color="orange")

# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# ## Build a Histogram (3): compare

# %% [markdown]
# Because we were using a histogram, it was very easy to make a $\color{red}{\text{comparison}}$.

# %% [markdown]
# Let's do a similar $\color{red}{\text{comparison}}$. $\color{blue}{\text{life_exp}}$ contains **life expectancy data for different countries in 2007**. You also have access to a second list now, $\color{blue}{\text{life_exp1950}}$, **containing similar data for 1950**. Can you make a histogram for both datasets?

# %%
# import numpy packages
import numpy as np

# import pandas
import pandas as pd

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# read csv file: gdp_csv
gdp_csv = pd.read_csv("gapminder.csv")

# create numpy arrays for csv files: np_gdp_csv
np_gdp_csv = np.array(gdp_csv)

# create life_exp for life expectancy for each country in 2007
life_exp = list(np_gdp_csv[:,5])

# create life_exp1950 for life expectancy for each country in 1950
life_exp1950 = list(np.loadtxt('life_exp1950.txt', dtype=float))

# Histogram of life_exp, 15 bins
plt.hist(life_exp, bins=15, edgecolor="white", color="black")

# Show and clear plot
plt.show()
plt.clf()

# Histogram of life_exp1950, 15 bins
plt.hist(life_exp1950, bins=15, edgecolor="black", color="white")

# Show and clear plot again
plt.show()
plt.clf()

# %% [markdown]
# ## Choose The Right Plot (1)

# %% [markdown]
# You're a **professor teaching Data Science** with $\color{red}{\text{Python}}$, and you want to visually assess if the **grades on your exam** follow a $\color{blue}{\text{particular distribution}}$. Which plot do you use?

# %% [markdown]
# **Possible answers:**
# <ul>
#     <li><input type="checkbox"> Line Plot</li>
#     <li><input type="checkbox"> Scatter Plot</li>
#     <li><input type="checkbox" checked> $\color{blue}{\text{Histogram}}$</li>
# </ul>

# %% [markdown]
# ## Choose The Right Plot (2)

# %% [markdown]
# You're a **professor in Data Analytics** with $\color{red}{\text{Python}}$, and you want to visually assess if **longer answers on exam questions** $\color{blue}{\text{lead to higher grades}}$. Which plot do you use?

# %% [markdown]
# **Possible answers:**
# <ul>
#     <li><input type="checkbox"> Line Plot</li>
#     <li><input type="checkbox" checked> Scatter Plot</li>
#     <li><input type="checkbox"> $\color{blue}{\text{Histogram}}$</li>
# </ul>

# %% [markdown]
# ## Labels

# %% [markdown]
# It's time to customize your own plot. This is the fun part, you will see your plot come to life!

# %% [markdown]
# You're going to work on the scatter plot with world development data: GDP per capita on the x-axis (logarithmic scale), life expectancy on the y-axis.

# %% [markdown]
# As a first step, let's add axis labels and a title to the plot. You can do this with the $\color{blue}{\text{xlabel()}}$, $\color{blue}{\text{ylabel()}}$ and $\color{blue}{\text{title()}}$ functions, available in $\color{blue}{\text{matplotlib.pyplot}}$.

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# read CSV file with pandas packages
read_csv = pd.read_csv("gapminder.csv")

# create np_read_csv to make list numpy arrays
np_read_csv = np.array(read_csv)

# create list gdp_cap for GDP per Capita [in USD]
gdp_cap = list(np_read_csv[:, 6])

# create list life_exp for Life Expectancy [in years]
list_exp = list(np_read_csv[:, 5])

# Basic scatter plot, log scale
plt.scatter(gdp_cap, life_exp)
plt.xscale('log')

# Strings for xlab, ylab, and title
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# create plt.xlabel, plt.ylabel, and plt.title for add axis label and title
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)

# create plt.show() for display the plot
plt.show()

# %% [markdown]
# ## Ticks

# %% [markdown]
# The customizations you've coded up to now are available in the script, in a more concise form.

# %% [markdown]
# In the video, Hugo has demonstrated how you could control the y-ticks by specifying two arguments:

# %%
plt.yticks([0,1,2], ["one","two","three"])

# %% [markdown]
# In this example, the ticks corresponding to the numbers 0, 1 and 2 will be replaced by one, two and three, respectively.

# %% [markdown]
# Let's do a similar thing for the **x-axis** of your world development chart, with the $\color{blue}{\text{xticks()}}$ function. The $\color{red}{\text{tick values}}$ **1000, 10000 and 100000** should $\color{red}{\text{be replaced}}$ by **1k, 10k and 100k**. To this end, two lists have already been created for you: $\color{blue}{\text{tick_val}}$ and $\color{blue}{\text{tick_lab}}$.

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# create_csv for open csv file
create_csv = pd.read_csv("gapminder.csv")

# create list with numpy arrays: np_create_csv
np_create_csv = np.array(create_csv)

# create list gdp_cap for GDP per Capita [in USD]
gpd_cap = list(np_create_csv[:,6])

# create list life_exp for Life Expectancy [in years]
life_exp = list(np_create_csv[:,5])

# Scatter plot for x-axis is gdp_cap and y-axis is life_exp 
plt.scatter(gpd_cap, life_exp)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val, tick_lab)

# After customizing, display the plot
plt.show()

# %% [markdown]
# ## Sizes

# %% [markdown]
# Right now, the scatter plot is just a cloud of blue dots, indistinguishable from each other. Let's change this. Wouldn't it be nice if the size of the dots corresponds to the population?

# %% [markdown]
# To accomplish this, there is a list $\color{blue}{\text{pop}}$ loaded in your workspace. It contains population numbers for each country expressed in millions. You can see that this list is added to the scatter method, as the argument $\color{blue}{\text{s}}$, for size.

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# create_csv for open csv file
create_csv = pd.read_csv("gapminder.csv")

# create list with numpy arrays: np_create_csv
np_create_csv = np.array(create_csv)

# create list gdp_cap for GDP per Capita [in USD]
gpd_cap = list(np_create_csv[:,6])

# create list life_exp for Life Expectancy [in years]
life_exp = list(np_create_csv[:,5])

# create list pop for population
pop = list(np_create_csv[:,3] * 0.000001)

# Store pop as a numpy array: np_pop
np_pop = np.array(pop)

# Double np_pop
np_pop = np_pop*2

# Scatter plot for x-axis is gdp_cap, y-axis is life_exp and s for size  
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])

# After customizing, display the plot
plt.show()

# %% [markdown]
# ## Colors

# %% [markdown]
# The next step is making the plot more colorful! To do this, a list $\color{blue}{\text{col}}$ has been created for you. It's a list with a color for each corresponding country, depending on the continent the country is part of.

# %% [markdown]
# How did we make the list $\color{blue}{\text{col}}$ you ask? The Gapminder data contains a list continent with the $\color{blue}{\text{continent}}$ each country belongs to. A dictionary is constructed that maps continents onto colors:

# %%
dict = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
}

# %% [markdown]
# Nothing to worry about now; you will learn about dictionaries in the next chapter.

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# create_csv for open csv file
create_csv = pd.read_csv("gapminder.csv")

# create list with numpy arrays: np_create_csv
np_create_csv = np.array(create_csv)

# create list gdp_cap for GDP per Capita [in USD]
gpd_cap = list(np_create_csv[:,6])

# create list life_exp for Life Expectancy [in years]
life_exp = list(np_create_csv[:,5])

# create list pop for population
pop = list(np_create_csv[:,3] * 0.000001)

#create color_txt for open color.txt
color_txt = list(np.loadtxt("col.txt", dtype=str))

# Specify c and alpha inside plt.scatter()
plt.scatter(gdp_cap, life_exp, s = np.array(pop) * 4, c = color_txt, alpha=0.5)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])

# After customizing, display the plot
plt.show()

# %% [markdown]
# ## Additional Customizations

# %% [markdown]
# If you have another look at the script, under $\color{green}{\text{# Additional Customizations}}$, you'll see that there are two $\color{blue}{\text{plt.text()}}$  functions now. They add the words $\color{red}{\text{"India"}}$ and $\color{red}{\text{"China"}}$ in the plot.

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# create_csv for open csv file
create_csv = pd.read_csv("gapminder.csv")

# create list with numpy arrays: np_create_csv
np_create_csv = np.array(create_csv)

# create list gdp_cap for GDP per Capita [in USD]
gpd_cap = list(np_create_csv[:,6])

# create list life_exp for Life Expectancy [in years]
life_exp = list(np_create_csv[:,5])

# create list pop for population
pop = list(np_create_csv[:,3] * 0.000001)

#create color_txt for open color.txt
color_txt = list(np.loadtxt("col.txt", dtype=str))

# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 4, c = color_txt, alpha=0.5)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Interpretation

# %%
# import numpy packages
import numpy as np

# import pandas packages
import pandas as pd

# import matplotlib packages
import matplotlib.pyplot as plt

# create_csv for open csv file
create_csv = pd.read_csv("gapminder.csv")

# create list with numpy arrays: np_create_csv
np_create_csv = np.array(create_csv)

# create list gdp_cap for GDP per Capita [in USD]
gpd_cap = list(np_create_csv[:,6])

# create list life_exp for Life Expectancy [in years]
life_exp = list(np_create_csv[:,5])

# create list pop for population
pop = list(np_create_csv[:,3] * 0.000001)

#create color_txt for open color.txt
color_txt = list(np.loadtxt("col.txt", dtype=str))

# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = color_txt, alpha=0.5)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# If you have a look at your colorful plot, it's clear that people live longer in countries with a higher GDP per capita. No high income countries have really short life expectancy, and no low income countries have very long life expectancy. Still, there is a huge difference in life expectancy between countries on the same income level. Most people live in middle income countries where difference in lifespan is huge between countries; depending on how income is distributed and how it is used.

# %% [markdown]
# What can you say about the plot?

# %% [markdown]
# **Possible answers:**
# <ul>
#     <li><input type="checkbox" checked> The countries in blue, corresponding to Africa, have both low life expectancy and a low GDP per capita</li>
#     <li><input type="checkbox"> There is a negative correlation between GDP per capita and life expectancy.</li>
#     <li><input type="checkbox"> China has both a lower GDP per capita and lower life expectancy compared to India.</li>
# </ul>
